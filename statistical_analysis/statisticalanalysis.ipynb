# %%
install.packages("ScottKnottESD")
library(ScottKnottESD)

# %%
install.packages("psych")               # Install psych package
library("psych")

# %%
vector1 <- c('Bank','Adult','Credit','German','Compas','LawSchool',
                'Student','Crime','Kdd-census','Dutch','Diabetes','OULAD')

for (value1 in vector1) {
  i=0
  s1 <-paste('/content/New_sorted_' , value1 ,'.csv',sep='',collapse = '')
  sorted_result <- read.csv(file = s1)
  sorted_result<- sorted_result[c(2:ncol(sorted_result))]
  sk <- sk_esd(sorted_result, version="np")
  print(sk)
}

# %%
vector1 <- c('Bank','Adult','Credit','German','Compas','LawSchool',
                'Student','Crime','Kdd-census','Dutch','Diabetes','OULAD')

for (value1 in vector1) {
  i=0
  s1 <-paste('/content/New_sorted_' , value1 ,'.csv',sep='',collapse = '')
  hdidi <- read.csv(file = s1)
  print(harmonic.mean(hdidi))
}
